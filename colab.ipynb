# %% [markdown]
# # Talking Head(?) Anime from a Single Image 3: Now the Body Too (Manual Poser Tool)
#
# **Instruction**
#
# 1. Run the four cells below, one by one, in order by clicking the "Play" button to the left of it. Wait for each cell to finish before going to the next one.
# 2. Scroll down to the end of the last cell, and play with the GUI.
#
# **Links**
#
# * Github repository: http://github.com/pkhungurn/talking-head-anime-3-demo
# * Project writeup: http://pkhungurn.github.io/talking-head-anime-3/

# %%
# Clone the repository
# %cd /content
# !git clone https://github.com/pkhungurn/talking-head-anime-3-demo.git
# Out:
# /content
# fatal: destination path 'talking-head-anime-3-demo' already exists and is not an empty directory.

# %%
# CD into the repository directory.
# %cd /content/talking-head-anime-3-demo
# Out:
# /content/talking-head-anime-3-demo

# %%
# Download model files
# !mkdir -p data/models/standard_float
# !wget -O data/models/standard_float/editor.pt https://www.dropbox.com/s/zp3e5ox57sdws3y/editor.pt?dl=0
# !wget -O data/models/standard_float/eyebrow_decomposer.pt https://www.dropbox.com/s/bcp42knbrk7egk8/eyebrow_decomposer.pt?dl=0
# !wget -O data/models/standard_float/eyebrow_morphing_combiner.pt https://www.dropbox.com/s/oywaiio2s53lc57/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/models/standard_float/face_morpher.pt https://www.dropbox.com/s/8qvo0u5lw7hqvtq/face_morpher.pt?dl=0
# !wget -O data/models/standard_float/two_algo_face_body_rotator.pt https://www.dropbox.com/s/qmq1dnxrmzsxb4h/two_algo_face_body_rotator.pt?dl=0

# !mkdir -p data/models/standard_half
# !wget -O data/models/standard_half/editor.pt https://www.dropbox.com/s/g21ps8gfuvz4kbo/editor.pt?dl=0
# !wget -O data/models/standard_half/eyebrow_decomposer.pt https://www.dropbox.com/s/nwwwevzpmxiilgn/eyebrow_decomposer.pt?dl=0
# !wget -O data/models/standard_half/eyebrow_morphing_combiner.pt https://www.dropbox.com/s/z5v0amgqif7yup1/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/models/standard_half/face_morpher.pt https://www.dropbox.com/s/g03sfnd5yfs0m65/face_morpher.pt?dl=0
# !wget -O data/models/standard_half/two_algo_face_body_rotator.pt https://www.dropbox.com/s/c5lrn7z34x12317/two_algo_face_body_rotator.pt?dl=0

# !mkdir -p data/models/separable_float
# !wget -O data/models/separable_float/editor.pt https://www.dropbox.com/s/nwdxhrpa9fy19r4/editor.pt?dl=0
# !wget -O data/models/separable_float/eyebrow_decomposer.pt https://www.dropbox.com/s/hfzjcu9cqr9wm3i/eyebrow_decomposer.pt?dl=0
# !wget -O data/models/separable_float/eyebrow_morphing_combiner.pt https://www.dropbox.com/s/g04dyyyavh5o1e2/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/models/separable_float/face_morpher.pt https://www.dropbox.com/s/vgi9dsj95y0rrwv/face_morpher.pt?dl=0
# !wget -O data/models/separable_float/two_algo_face_body_rotator.pt https://www.dropbox.com/s/8u0qond8po34l24/two_algo_face_body_rotator.pt?dl=0

# !mkdir -p data/models/separable_half
# !wget -O data/models/separable_half/editor.pt https://www.dropbox.com/s/on8kn6z9fj95j0h/editor.pt?dl=0
# !wget -O data/models/separable_half/eyebrow_decomposer.pt https://www.dropbox.com/s/0hxu8opu1hmghqe/eyebrow_decomposer.pt?dl=0
# !wget -O data/models/separable_half/eyebrow_morphing_combiner.pt https://www.dropbox.com/s/bgz02afp0xojqfs/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/models/separable_half/face_morpher.pt https://www.dropbox.com/s/bgz02afp0xojqfs/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/models/separable_half/two_algo_face_body_rotator.pt https://www.dropbox.com/s/vr8h2xxltszhw7w/two_algo_face_body_rotator.pt?dl=0
# Out:
# --2025-07-01 11:26:12--  https://www.dropbox.com/s/zp3e5ox57sdws3y/editor.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/o3b874e1yxh959qtemec6/editor.pt?rlkey=9nuoudpgvrv5b2u3uw420l8gh&dl=0 [following]
# --2025-07-01 11:26:12--  https://www.dropbox.com/scl/fi/o3b874e1yxh959qtemec6/editor.pt?rlkey=9nuoudpgvrv5b2u3uw420l8gh&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9e842cbd649b4f84e2a38b435b.dl.dropboxusercontent.com/cd/0/inline/Csqa_0oOAGNG64Bi53eEI_rt28pA5uyX6qgGANLTWdTFvPVvQn4SRqybOvSCRnh8uGt2AbGX0bmx5kYNF7IsZBxDIlSqjF0tPVjPgJZycfYlY2-d5b7dnzYKKoVDjqNZkNY/file# [following]
# --2025-07-01 11:26:12--  https://uc9e842cbd649b4f84e2a38b435b.dl.dropboxusercontent.com/cd/0/inline/Csqa_0oOAGNG64Bi53eEI_rt28pA5uyX6qgGANLTWdTFvPVvQn4SRqybOvSCRnh8uGt2AbGX0bmx5kYNF7IsZBxDIlSqjF0tPVjPgJZycfYlY2-d5b7dnzYKKoVDjqNZkNY/file
# Resolving uc9e842cbd649b4f84e2a38b435b.dl.dropboxusercontent.com (uc9e842cbd649b4f84e2a38b435b.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6022:15::a27d:420f
# Connecting to uc9e842cbd649b4f84e2a38b435b.dl.dropboxusercontent.com (uc9e842cbd649b4f84e2a38b435b.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Csow-q8sJ374ctuJA2UrxpFU0z8xlbRHTEYMO2hiTdvC7bFdbNcM1RGRfTLBa17ebBNeKD-3aPayy8wKR96X0ml_nnS-ZdZTwA0MKUdMszezpKYxadJKOe_EuYGDAfTvPousbRPyM1qrHl5OGSq-P4h2n4gShMjHaA9abuAfPCjRuNIA99y_sZ7mYbPLP6biRf63oO3kZgT-9ShyBbgK3XWmj0syFyyPW1_4MejCmm5iHt2DtfZY7-9koDRGkVmSHW8Jd4MNzgjA-eTVd3i1fW7n4sWcGN5xTcN6_ATgmgouPgqMlnHhf58pz5BHROL5cJOmU4aFMOe8wemxG93AejklK0o9ZwwB1YJhGN8mZjPaPw/file [following]
# --2025-07-01 11:26:13--  https://uc9e842cbd649b4f84e2a38b435b.dl.dropboxusercontent.com/cd/0/inline2/Csow-q8sJ374ctuJA2UrxpFU0z8xlbRHTEYMO2hiTdvC7bFdbNcM1RGRfTLBa17ebBNeKD-3aPayy8wKR96X0ml_nnS-ZdZTwA0MKUdMszezpKYxadJKOe_EuYGDAfTvPousbRPyM1qrHl5OGSq-P4h2n4gShMjHaA9abuAfPCjRuNIA99y_sZ7mYbPLP6biRf63oO3kZgT-9ShyBbgK3XWmj0syFyyPW1_4MejCmm5iHt2DtfZY7-9koDRGkVmSHW8Jd4MNzgjA-eTVd3i1fW7n4sWcGN5xTcN6_ATgmgouPgqMlnHhf58pz5BHROL5cJOmU4aFMOe8wemxG93AejklK0o9ZwwB1YJhGN8mZjPaPw/file
# Reusing existing connection to uc9e842cbd649b4f84e2a38b435b.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 33471839 (32M) [application/octet-stream]
# Saving to: ‘data/models/standard_float/editor.pt’
#
# data/models/standar 100%[===================>]  31.92M  16.1MB/s    in 2.0s
#
# 2025-07-01 11:26:16 (16.1 MB/s) - ‘data/models/standard_float/editor.pt’ saved [33471839/33471839]
#
# --2025-07-01 11:26:16--  https://www.dropbox.com/s/bcp42knbrk7egk8/eyebrow_decomposer.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/b1lpiqotfnfprjzvmjr39/eyebrow_decomposer.pt?rlkey=2ln7c5s6ij0xqgtnmnj63wv8d&dl=0 [following]
# --2025-07-01 11:26:16--  https://www.dropbox.com/scl/fi/b1lpiqotfnfprjzvmjr39/eyebrow_decomposer.pt?rlkey=2ln7c5s6ij0xqgtnmnj63wv8d&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucefa0714752caad0652b286c386.dl.dropboxusercontent.com/cd/0/inline/CsohWwp87qAjYa7_NdugAbj8bV8I74-lTqs3nrGudSfsSjHAN2Z0EiSKXoUbg9ScqfA_6hWjIVA7PbkW0pdlJitinsTCNr5yXwq2U8RiqdNNDXa_f7ewWvoY1C0VHM4m5GE/file# [following]
# --2025-07-01 11:26:16--  https://ucefa0714752caad0652b286c386.dl.dropboxusercontent.com/cd/0/inline/CsohWwp87qAjYa7_NdugAbj8bV8I74-lTqs3nrGudSfsSjHAN2Z0EiSKXoUbg9ScqfA_6hWjIVA7PbkW0pdlJitinsTCNr5yXwq2U8RiqdNNDXa_f7ewWvoY1C0VHM4m5GE/file
# Resolving ucefa0714752caad0652b286c386.dl.dropboxusercontent.com (ucefa0714752caad0652b286c386.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6021:15::a27d:410f
# Connecting to ucefa0714752caad0652b286c386.dl.dropboxusercontent.com (ucefa0714752caad0652b286c386.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CspdDLeVbpqpHG6-3IMuviwFd7NsV_S5MpBI0ws3aESp9eAg9DYr2SkoJCuXfKFS4Jo7Hra2IklJecL-VqMPhQsyrvrB0V-6DxbBzePOaDRI-vtOzrBNkifrLMCykdKbZrJejhy2zZy8f79-Z3fFq6Jm7nZrm41K6krLggHM-pgfLE2mVm5q4EbNL-wcY5iUtrbjaW-w0R6b_GiRvlbvh1O-103r5mYtWmnSORRZyWsgwL6OA466PqOkyNeTbiyk0Njcx4tqf974JMkCe0UoFH8ys6x-0CTHu1m1A5NffAJVq4onue0-Ng3AeoSlUPDqa9lKMuLGr-KgX-JlXsdiBoTYM6PdgNxQ01Kqmzzrx0HhXw/file [following]
# --2025-07-01 11:26:17--  https://ucefa0714752caad0652b286c386.dl.dropboxusercontent.com/cd/0/inline2/CspdDLeVbpqpHG6-3IMuviwFd7NsV_S5MpBI0ws3aESp9eAg9DYr2SkoJCuXfKFS4Jo7Hra2IklJecL-VqMPhQsyrvrB0V-6DxbBzePOaDRI-vtOzrBNkifrLMCykdKbZrJejhy2zZy8f79-Z3fFq6Jm7nZrm41K6krLggHM-pgfLE2mVm5q4EbNL-wcY5iUtrbjaW-w0R6b_GiRvlbvh1O-103r5mYtWmnSORRZyWsgwL6OA466PqOkyNeTbiyk0Njcx4tqf974JMkCe0UoFH8ys6x-0CTHu1m1A5NffAJVq4onue0-Ng3AeoSlUPDqa9lKMuLGr-KgX-JlXsdiBoTYM6PdgNxQ01Kqmzzrx0HhXw/file
# Reusing existing connection to ucefa0714752caad0652b286c386.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 125942879 (120M) [application/octet-stream]
# Saving to: ‘data/models/standard_float/eyebrow_decomposer.pt’
#
# data/models/standar 100%[===================>] 120.11M  16.8MB/s    in 6.5s
#
# 2025-07-01 11:26:24 (18.5 MB/s) - ‘data/models/standard_float/eyebrow_decomposer.pt’ saved [125942879/125942879]
#
# --2025-07-01 11:26:24--  https://www.dropbox.com/s/oywaiio2s53lc57/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/zsclsyc5loscbaqmk1512/eyebrow_morphing_combiner.pt?rlkey=3q21ob8w57x1gr6jedl7ge12o&dl=0 [following]
# --2025-07-01 11:26:24--  https://www.dropbox.com/scl/fi/zsclsyc5loscbaqmk1512/eyebrow_morphing_combiner.pt?rlkey=3q21ob8w57x1gr6jedl7ge12o&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc33809f6fa8f55b33604ae17211.dl.dropboxusercontent.com/cd/0/inline/CspBbTg-9p7BUi22t1n0891IpfwI9ufTJWiF_qaHwiLHgqlowsC9yA7SvyFJ6WTpVs_oQEEJekzPbv3uauB2pGQYAkTE4taQhz7AzEWmzSiwBM1iNJfmLRvMcevtOZLwoIc/file# [following]
# --2025-07-01 11:26:25--  https://uc33809f6fa8f55b33604ae17211.dl.dropboxusercontent.com/cd/0/inline/CspBbTg-9p7BUi22t1n0891IpfwI9ufTJWiF_qaHwiLHgqlowsC9yA7SvyFJ6WTpVs_oQEEJekzPbv3uauB2pGQYAkTE4taQhz7AzEWmzSiwBM1iNJfmLRvMcevtOZLwoIc/file
# Resolving uc33809f6fa8f55b33604ae17211.dl.dropboxusercontent.com (uc33809f6fa8f55b33604ae17211.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6022:15::a27d:420f
# Connecting to uc33809f6fa8f55b33604ae17211.dl.dropboxusercontent.com (uc33809f6fa8f55b33604ae17211.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CsqwKIRa3b6PxVSB-qgsD-ms_2eFxJuDKeB-TalUgqG0A3MPqxOGkx4TS2BU3b6HJK66yJvFZ8FbFtHHdWAgPuGm295KSm3Q149C-of_mSH3OTR6TiQ7hbJdT9zqNyNMLxzryBdtknRr0Zo7GQwQySBulwTXY5oQlzBvwtfJpqejkTYmTLEzsvFGwf7JAWVzwzcw3CA4S_sctn_2Q7m87uhWbdcMoYlfurLk_pjt5QrIiNR-aJ-DrYRMxd50Y4C_3Yzc3A6ALmunxYq1CqHGQjrcmSNkREudDwIJiZ5KNla9muRcDfqb8F970MlXVzek8L4G9_pourNIc9mxRI_q2Xa2QQZb6OAhHErN1f2P7Xh-Mg/file [following]
# --2025-07-01 11:26:26--  https://uc33809f6fa8f55b33604ae17211.dl.dropboxusercontent.com/cd/0/inline2/CsqwKIRa3b6PxVSB-qgsD-ms_2eFxJuDKeB-TalUgqG0A3MPqxOGkx4TS2BU3b6HJK66yJvFZ8FbFtHHdWAgPuGm295KSm3Q149C-of_mSH3OTR6TiQ7hbJdT9zqNyNMLxzryBdtknRr0Zo7GQwQySBulwTXY5oQlzBvwtfJpqejkTYmTLEzsvFGwf7JAWVzwzcw3CA4S_sctn_2Q7m87uhWbdcMoYlfurLk_pjt5QrIiNR-aJ-DrYRMxd50Y4C_3Yzc3A6ALmunxYq1CqHGQjrcmSNkREudDwIJiZ5KNla9muRcDfqb8F970MlXVzek8L4G9_pourNIc9mxRI_q2Xa2QQZb6OAhHErN1f2P7Xh-Mg/file
# Reusing existing connection to uc33809f6fa8f55b33604ae17211.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126168279 (120M) [application/octet-stream]
# Saving to: ‘data/models/standard_float/eyebrow_morphing_combiner.pt’
#
# data/models/standar 100%[===================>] 120.32M  37.2MB/s    in 3.3s
#
# 2025-07-01 11:26:29 (36.1 MB/s) - ‘data/models/standard_float/eyebrow_morphing_combiner.pt’ saved [126168279/126168279]
#
# --2025-07-01 11:26:30--  https://www.dropbox.com/s/8qvo0u5lw7hqvtq/face_morpher.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/6v8tnb69ukpkbif0i80tl/face_morpher.pt?rlkey=f2uzl39kv882beogkl34lk3lq&dl=0 [following]
# --2025-07-01 11:26:30--  https://www.dropbox.com/scl/fi/6v8tnb69ukpkbif0i80tl/face_morpher.pt?rlkey=f2uzl39kv882beogkl34lk3lq&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4b7ae9b7a2103dadc862dca80b.dl.dropboxusercontent.com/cd/0/inline/Csph9UXCONd6Kc17IrIRMhEC6I_jSCF86NTETPSlE-D3Zy1VNlDVXgdqeW35GK0zOCmrQRxcuzoOrwgLB5OhbIyuyGd0EOGnNfeVyMrzaHPMCGCAHBLRztQYwLek_wwLFOw/file# [following]
# --2025-07-01 11:26:30--  https://uc4b7ae9b7a2103dadc862dca80b.dl.dropboxusercontent.com/cd/0/inline/Csph9UXCONd6Kc17IrIRMhEC6I_jSCF86NTETPSlE-D3Zy1VNlDVXgdqeW35GK0zOCmrQRxcuzoOrwgLB5OhbIyuyGd0EOGnNfeVyMrzaHPMCGCAHBLRztQYwLek_wwLFOw/file
# Resolving uc4b7ae9b7a2103dadc862dca80b.dl.dropboxusercontent.com (uc4b7ae9b7a2103dadc862dca80b.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6022:15::a27d:420f
# Connecting to uc4b7ae9b7a2103dadc862dca80b.dl.dropboxusercontent.com (uc4b7ae9b7a2103dadc862dca80b.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Csq1Rs8bRREbZq1ImAwxSFtQDQkIuvpyygygvoZxJEFa2v7RPIyxBr4NZQgnC28Y0Uba5XgSstsCPwBcQSWf4jOcGLA5F9SskzJURNpmEVpNVRXDf7E4qYjRfyqw2ZEpUXwzYi8mQPMcE28HRzvQyuMyljPujbVd-ddBoKY_FVJQCBUNdp9NspInvvnop4nGygEsbKsGbmVa356o1qOPJIWHDvsvjveD_iFrB2Gyqqhu6EIfpqUn-zXGj5PviJw46AINMmg7DbtVgZMTGtk48kEhBZByI1V70SH9NkAfsA1rQWl1Vf0ToW__uFfH5u1Y7LeB4Rohy3-J1dv9vrR_1O85xur0N993loXXiTF0Iz1NOQ/file [following]
# --2025-07-01 11:26:31--  https://uc4b7ae9b7a2103dadc862dca80b.dl.dropboxusercontent.com/cd/0/inline2/Csq1Rs8bRREbZq1ImAwxSFtQDQkIuvpyygygvoZxJEFa2v7RPIyxBr4NZQgnC28Y0Uba5XgSstsCPwBcQSWf4jOcGLA5F9SskzJURNpmEVpNVRXDf7E4qYjRfyqw2ZEpUXwzYi8mQPMcE28HRzvQyuMyljPujbVd-ddBoKY_FVJQCBUNdp9NspInvvnop4nGygEsbKsGbmVa356o1qOPJIWHDvsvjveD_iFrB2Gyqqhu6EIfpqUn-zXGj5PviJw46AINMmg7DbtVgZMTGtk48kEhBZByI1V70SH9NkAfsA1rQWl1Vf0ToW__uFfH5u1Y7LeB4Rohy3-J1dv9vrR_1O85xur0N993loXXiTF0Iz1NOQ/file
# Reusing existing connection to uc4b7ae9b7a2103dadc862dca80b.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126444711 (121M) [application/octet-stream]
# Saving to: ‘data/models/standard_float/face_morpher.pt’
#
# data/models/standar 100%[===================>] 120.59M  14.8MB/s    in 7.9s
#
# 2025-07-01 11:26:40 (15.2 MB/s) - ‘data/models/standard_float/face_morpher.pt’ saved [126444711/126444711]
#
# --2025-07-01 11:26:40--  https://www.dropbox.com/s/qmq1dnxrmzsxb4h/two_algo_face_body_rotator.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/2kla73670f0sz9c2s8nv1/two_algo_face_body_rotator.pt?rlkey=0qvgk6x0uefqyj3mmyhqm7q52&dl=0 [following]
# --2025-07-01 11:26:40--  https://www.dropbox.com/scl/fi/2kla73670f0sz9c2s8nv1/two_algo_face_body_rotator.pt?rlkey=0qvgk6x0uefqyj3mmyhqm7q52&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf619a926364d212b45e63598cb.dl.dropboxusercontent.com/cd/0/inline/Csr1fyD-smVwnYZUu5EyV2DCrdJLsB1vJYxIpVLmpdHEMFr6XiPRCwI89UouiQayqV979qsWrUfNP76sm43ylEB4tHDhA_AnKFq3DEmvg5trDLDVFlZnJh4JDXwQjWFhIVM/file# [following]
# --2025-07-01 11:26:40--  https://ucf619a926364d212b45e63598cb.dl.dropboxusercontent.com/cd/0/inline/Csr1fyD-smVwnYZUu5EyV2DCrdJLsB1vJYxIpVLmpdHEMFr6XiPRCwI89UouiQayqV979qsWrUfNP76sm43ylEB4tHDhA_AnKFq3DEmvg5trDLDVFlZnJh4JDXwQjWFhIVM/file
# Resolving ucf619a926364d212b45e63598cb.dl.dropboxusercontent.com (ucf619a926364d212b45e63598cb.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6021:15::a27d:410f
# Connecting to ucf619a926364d212b45e63598cb.dl.dropboxusercontent.com (ucf619a926364d212b45e63598cb.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CsrWHueAXWSeE-OrAxNMpbWmpfzKAFrP8p6iL413IuhacqR9-DrNFJYaO-WVS7M5zdzYtP1V34oy_EH_H9I8YbK9QSFvL0wsWdewmSzfB3tG5w-EHTU69rpQ2WI6cgO4c9YG6HtNHnIhm1bjRtzoNrLWHDu9sR2OPsQG0UcRTgYIpS2BbegFKJMhP3H9ExuFqqDiFQlEuoJ-Ga6-utXdMzywgMRZItQmGdmO0vNeFNNUWlRN_6QQkXjLF6DfErtX8hmJaLfulkdQZrTBeEaT_JO7Twq6bLgn6dFjmLdiHBo-YnIVQ7v8mhAsDFU4HOiQSw35kp-8wb35hDsmVhoS_ju2nALfFZ2G7Z-JIjOVHCn1HA/file [following]
# --2025-07-01 11:26:41--  https://ucf619a926364d212b45e63598cb.dl.dropboxusercontent.com/cd/0/inline2/CsrWHueAXWSeE-OrAxNMpbWmpfzKAFrP8p6iL413IuhacqR9-DrNFJYaO-WVS7M5zdzYtP1V34oy_EH_H9I8YbK9QSFvL0wsWdewmSzfB3tG5w-EHTU69rpQ2WI6cgO4c9YG6HtNHnIhm1bjRtzoNrLWHDu9sR2OPsQG0UcRTgYIpS2BbegFKJMhP3H9ExuFqqDiFQlEuoJ-Ga6-utXdMzywgMRZItQmGdmO0vNeFNNUWlRN_6QQkXjLF6DfErtX8hmJaLfulkdQZrTBeEaT_JO7Twq6bLgn6dFjmLdiHBo-YnIVQ7v8mhAsDFU4HOiQSw35kp-8wb35hDsmVhoS_ju2nALfFZ2G7Z-JIjOVHCn1HA/file
# Reusing existing connection to ucf619a926364d212b45e63598cb.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 130675279 (125M) [application/octet-stream]
# Saving to: ‘data/models/standard_float/two_algo_face_body_rotator.pt’
#
# data/models/standar 100%[===================>] 124.62M  20.3MB/s    in 6.1s
#
# 2025-07-01 11:26:48 (20.6 MB/s) - ‘data/models/standard_float/two_algo_face_body_rotator.pt’ saved [130675279/130675279]
#
# --2025-07-01 11:26:48--  https://www.dropbox.com/s/g21ps8gfuvz4kbo/editor.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/olle06rhj0hqn7cs7biql/editor.pt?rlkey=ztc45wuh149oedwe9gko3crkg&dl=0 [following]
# --2025-07-01 11:26:48--  https://www.dropbox.com/scl/fi/olle06rhj0hqn7cs7biql/editor.pt?rlkey=ztc45wuh149oedwe9gko3crkg&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc49d119ca927bc43ef03731aa3c.dl.dropboxusercontent.com/cd/0/inline/Csq6s64_KibF7GX5s5nsfpe24gVFQG6p-fhwHN4re2pLjreHYCFRb2PTp-Ctg1Zh9J4m1G3cpCwHjagLbyNu8rfVO53_YKZJ9J0F59zepPjaEaEV1TY9ad9Z0H5T0Z8uOM4/file# [following]
# --2025-07-01 11:26:48--  https://uc49d119ca927bc43ef03731aa3c.dl.dropboxusercontent.com/cd/0/inline/Csq6s64_KibF7GX5s5nsfpe24gVFQG6p-fhwHN4re2pLjreHYCFRb2PTp-Ctg1Zh9J4m1G3cpCwHjagLbyNu8rfVO53_YKZJ9J0F59zepPjaEaEV1TY9ad9Z0H5T0Z8uOM4/file
# Resolving uc49d119ca927bc43ef03731aa3c.dl.dropboxusercontent.com (uc49d119ca927bc43ef03731aa3c.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6022:15::a27d:420f
# Connecting to uc49d119ca927bc43ef03731aa3c.dl.dropboxusercontent.com (uc49d119ca927bc43ef03731aa3c.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CspEx5QSojAdNCUmgSycs4kxTK9Wod-m_cXiOlxWd-Xl-Q7VuNJbmsxqLYKiVWSdFhGNoE6fgRQsdsPFzZJynJbU-Bj-RHje_bugpbMyuJMor9mdFSjumLa_f7ta4pjYKwRK5zht05lAU-TsPKmQHkJijM8a6GYvaiJdCOq6ZdTTon_yQpx63NYtjz7r3gKFeraHOjW3qwgAC8D7qJFrTyXV04JvBOD83AgnSpr6RsD2wsQxfQ9Z8kC5WcGDqOqeEcUecynRbQuzlLHt-hT16WyGyJUBiV66PuAHKm9MqrDBbGYrnhoQF8nBiQKucEQNU05qGYuEK1Y2nxFj6SO4j8Mjcl9f7sn3HQkBzxqZZnparg/file [following]
# --2025-07-01 11:26:49--  https://uc49d119ca927bc43ef03731aa3c.dl.dropboxusercontent.com/cd/0/inline2/CspEx5QSojAdNCUmgSycs4kxTK9Wod-m_cXiOlxWd-Xl-Q7VuNJbmsxqLYKiVWSdFhGNoE6fgRQsdsPFzZJynJbU-Bj-RHje_bugpbMyuJMor9mdFSjumLa_f7ta4pjYKwRK5zht05lAU-TsPKmQHkJijM8a6GYvaiJdCOq6ZdTTon_yQpx63NYtjz7r3gKFeraHOjW3qwgAC8D7qJFrTyXV04JvBOD83AgnSpr6RsD2wsQxfQ9Z8kC5WcGDqOqeEcUecynRbQuzlLHt-hT16WyGyJUBiV66PuAHKm9MqrDBbGYrnhoQF8nBiQKucEQNU05qGYuEK1Y2nxFj6SO4j8Mjcl9f7sn3HQkBzxqZZnparg/file
# Reusing existing connection to uc49d119ca927bc43ef03731aa3c.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16748511 (16M) [application/octet-stream]
# Saving to: ‘data/models/standard_half/editor.pt’
#
# data/models/standar 100%[===================>]  15.97M  18.9MB/s    in 0.8s
#
# 2025-07-01 11:26:50 (18.9 MB/s) - ‘data/models/standard_half/editor.pt’ saved [16748511/16748511]
#
# --2025-07-01 11:26:50--  https://www.dropbox.com/s/nwwwevzpmxiilgn/eyebrow_decomposer.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/6zlnpomzioe9g7y2xc6ss/eyebrow_decomposer.pt?rlkey=oalxswjc5f01jyfvfbd4npuaf&dl=0 [following]
# --2025-07-01 11:26:51--  https://www.dropbox.com/scl/fi/6zlnpomzioe9g7y2xc6ss/eyebrow_decomposer.pt?rlkey=oalxswjc5f01jyfvfbd4npuaf&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucef569f125772980103ef4f5cce.dl.dropboxusercontent.com/cd/0/inline/Csoxom7U8-Fu-l7BHaUnNa3atQXUotyfuKo8eS7R6TBVKC8ncVhYkTes8hvSD_BNshCDqh6Ob1jdgsv1YJSRSkar8cg3HoQ2FOfDlrTIOukGbGPHeEkDJFixFow42HkIjZA/file# [following]
# --2025-07-01 11:26:51--  https://ucef569f125772980103ef4f5cce.dl.dropboxusercontent.com/cd/0/inline/Csoxom7U8-Fu-l7BHaUnNa3atQXUotyfuKo8eS7R6TBVKC8ncVhYkTes8hvSD_BNshCDqh6Ob1jdgsv1YJSRSkar8cg3HoQ2FOfDlrTIOukGbGPHeEkDJFixFow42HkIjZA/file
# Resolving ucef569f125772980103ef4f5cce.dl.dropboxusercontent.com (ucef569f125772980103ef4f5cce.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to ucef569f125772980103ef4f5cce.dl.dropboxusercontent.com (ucef569f125772980103ef4f5cce.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Csq7OaHJQnBIu1QSKbq0bawYlhiBl0qbbuoiY5-BJuvDx46FMAtw4uxKZo9OW5tzwcvliO0NNROMiOgGX5r78jCuPSkyZu47NPc6djtUHzvOP_pjcsOPhe4OJxVqv1C7hv-gFSFLeUpRFA__ZrAypLvod8_pNwCdenXNwH3rfM6aAe0m-BIwm9XDoAgaGjiBLTpODz0WCxNsVO70KQ5wHjoEwCHvqohrjSwolWM20IxBsoFVMyDz6Q1FhWYyr3EhsOwjQ3P3q6eUSR9FR0485A-ty_IDpKBhPYV87rbCa0ljFrv7YdlTJjN5iF0jJg476fOWxSbWCcwYA7wD1sqvSxSoQSMfJAGwSVIjCiHLEfPugg/file [following]
# --2025-07-01 11:26:52--  https://ucef569f125772980103ef4f5cce.dl.dropboxusercontent.com/cd/0/inline2/Csq7OaHJQnBIu1QSKbq0bawYlhiBl0qbbuoiY5-BJuvDx46FMAtw4uxKZo9OW5tzwcvliO0NNROMiOgGX5r78jCuPSkyZu47NPc6djtUHzvOP_pjcsOPhe4OJxVqv1C7hv-gFSFLeUpRFA__ZrAypLvod8_pNwCdenXNwH3rfM6aAe0m-BIwm9XDoAgaGjiBLTpODz0WCxNsVO70KQ5wHjoEwCHvqohrjSwolWM20IxBsoFVMyDz6Q1FhWYyr3EhsOwjQ3P3q6eUSR9FR0485A-ty_IDpKBhPYV87rbCa0ljFrv7YdlTJjN5iF0jJg476fOWxSbWCcwYA7wD1sqvSxSoQSMfJAGwSVIjCiHLEfPugg/file
# Reusing existing connection to ucef569f125772980103ef4f5cce.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 62984031 (60M) [application/octet-stream]
# Saving to: ‘data/models/standard_half/eyebrow_decomposer.pt’
#
# data/models/standar 100%[===================>]  60.07M  23.4MB/s    in 2.6s
#
# 2025-07-01 11:26:55 (23.4 MB/s) - ‘data/models/standard_half/eyebrow_decomposer.pt’ saved [62984031/62984031]
#
# --2025-07-01 11:26:55--  https://www.dropbox.com/s/z5v0amgqif7yup1/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/mbjyelhvaf4rx635pyjtf/eyebrow_morphing_combiner.pt?rlkey=ojyjetp5gevpsnmuac4tnneu1&dl=0 [following]
# --2025-07-01 11:26:55--  https://www.dropbox.com/scl/fi/mbjyelhvaf4rx635pyjtf/eyebrow_morphing_combiner.pt?rlkey=ojyjetp5gevpsnmuac4tnneu1&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca36820f15fcff77e84afa3dbf3.dl.dropboxusercontent.com/cd/0/inline/Csron350ANtOjCymOSZSIGSE6oGX7AnwMK203ffUVThLmjv9XyEw1pMD2jwbh2vpumKMGR0n5IUsQjLGaTVUMobHeLSL_wSE7vCjvEjLEmKzknpuqcrPkvLifIHEOf_qlSc/file# [following]
# --2025-07-01 11:26:56--  https://uca36820f15fcff77e84afa3dbf3.dl.dropboxusercontent.com/cd/0/inline/Csron350ANtOjCymOSZSIGSE6oGX7AnwMK203ffUVThLmjv9XyEw1pMD2jwbh2vpumKMGR0n5IUsQjLGaTVUMobHeLSL_wSE7vCjvEjLEmKzknpuqcrPkvLifIHEOf_qlSc/file
# Resolving uca36820f15fcff77e84afa3dbf3.dl.dropboxusercontent.com (uca36820f15fcff77e84afa3dbf3.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6021:15::a27d:410f
# Connecting to uca36820f15fcff77e84afa3dbf3.dl.dropboxusercontent.com (uca36820f15fcff77e84afa3dbf3.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CsoFEXZYgXW63poonI4yKH4qSFcPE9jTvrAIcHaTV9QtDTPSscq1Z8IGsuLuMvJe9xJAr4b7HRkyy-addsbVqMAbBwPH54H__NLuBERvYcEW5JY5trAEFkMSI9BJBdLarIPqauSM3pNB25wVvMfX86yF3gqqa46BeWC10IfStn40qbGqbdXIWuvsKX0qRcu_XcU5Ee-j-tRU47aNum56mWy7H9YD14Us5viWu5BDOvDja7-ZcCkSmVl6eBk4jnxW8WEJ9pxBCoWY_DFHs7_EOLmjr2BjNm68bu08SKEVdcJa9QqomvMRkDQ0lY2HNAbI7HCI3JNFufaPB4LeC-PHCFKR-kSiBPfHpdXdy2Q4wbi0Mw/file [following]
# --2025-07-01 11:26:56--  https://uca36820f15fcff77e84afa3dbf3.dl.dropboxusercontent.com/cd/0/inline2/CsoFEXZYgXW63poonI4yKH4qSFcPE9jTvrAIcHaTV9QtDTPSscq1Z8IGsuLuMvJe9xJAr4b7HRkyy-addsbVqMAbBwPH54H__NLuBERvYcEW5JY5trAEFkMSI9BJBdLarIPqauSM3pNB25wVvMfX86yF3gqqa46BeWC10IfStn40qbGqbdXIWuvsKX0qRcu_XcU5Ee-j-tRU47aNum56mWy7H9YD14Us5viWu5BDOvDja7-ZcCkSmVl6eBk4jnxW8WEJ9pxBCoWY_DFHs7_EOLmjr2BjNm68bu08SKEVdcJa9QqomvMRkDQ0lY2HNAbI7HCI3JNFufaPB4LeC-PHCFKR-kSiBPfHpdXdy2Q4wbi0Mw/file
# Reusing existing connection to uca36820f15fcff77e84afa3dbf3.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 63096535 (60M) [application/octet-stream]
# Saving to: ‘data/models/standard_half/eyebrow_morphing_combiner.pt’
#
# data/models/standar 100%[===================>]  60.17M  21.4MB/s    in 2.8s
#
# 2025-07-01 11:27:00 (21.4 MB/s) - ‘data/models/standard_half/eyebrow_morphing_combiner.pt’ saved [63096535/63096535]
#
# --2025-07-01 11:27:00--  https://www.dropbox.com/s/g03sfnd5yfs0m65/face_morpher.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/z2pn8sqe6x2lsx2rkaz4j/face_morpher.pt?rlkey=vg8m0a4yojho7ve1gx7xfd1jm&dl=0 [following]
# --2025-07-01 11:27:00--  https://www.dropbox.com/scl/fi/z2pn8sqe6x2lsx2rkaz4j/face_morpher.pt?rlkey=vg8m0a4yojho7ve1gx7xfd1jm&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucbc2ac089a1538f231fb7eb046d.dl.dropboxusercontent.com/cd/0/inline/Cso7u0FI4wMT2emefuZmZJ3tlOjodZnALNmtqy9bYqN9ucY8pFIZ0eDND2XG6t0A4tAgqq-CfqYvMyaem1kCmputaHBh0nU23CZ4wXu_HsyHBfSUd72byqXD-LlNHb86EhE/file# [following]
# --2025-07-01 11:27:00--  https://ucbc2ac089a1538f231fb7eb046d.dl.dropboxusercontent.com/cd/0/inline/Cso7u0FI4wMT2emefuZmZJ3tlOjodZnALNmtqy9bYqN9ucY8pFIZ0eDND2XG6t0A4tAgqq-CfqYvMyaem1kCmputaHBh0nU23CZ4wXu_HsyHBfSUd72byqXD-LlNHb86EhE/file
# Resolving ucbc2ac089a1538f231fb7eb046d.dl.dropboxusercontent.com (ucbc2ac089a1538f231fb7eb046d.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6027:15::a27d:480f
# Connecting to ucbc2ac089a1538f231fb7eb046d.dl.dropboxusercontent.com (ucbc2ac089a1538f231fb7eb046d.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CsoAGM8luy9R0xvTlC9OVsBDXP4L5jkz3K4A3W73l6Fgu3hzQdWwXIUYm709brLAlqLnA5LsGTyjvCih51OeMX99SVPDt7S1nk4bbeRH31S_7RMWGQmzC8x1dE4o-5gOke4wlcEnVQt3UzUUzZAdexnxUD6AEkWMlPl1_stwyJwjLXyGE3hotgExdS-viYoRURty2DabjPpm_imOfAsABpHvtVvmrG7VAJ-HRAM7t6JyWB7ji-wiGA562fjFgMJxxI-AcSqZFupNC9y9z3VwOuPnsuPq7MKSngyAs-z9Gg6NECDkMztAIznt7pCPJG58hBQx_Lfe_QTaeqEdstWiiE0nAm4gHSeEkw99mvwgyQ0_Sg/file [following]
# --2025-07-01 11:27:01--  https://ucbc2ac089a1538f231fb7eb046d.dl.dropboxusercontent.com/cd/0/inline2/CsoAGM8luy9R0xvTlC9OVsBDXP4L5jkz3K4A3W73l6Fgu3hzQdWwXIUYm709brLAlqLnA5LsGTyjvCih51OeMX99SVPDt7S1nk4bbeRH31S_7RMWGQmzC8x1dE4o-5gOke4wlcEnVQt3UzUUzZAdexnxUD6AEkWMlPl1_stwyJwjLXyGE3hotgExdS-viYoRURty2DabjPpm_imOfAsABpHvtVvmrG7VAJ-HRAM7t6JyWB7ji-wiGA562fjFgMJxxI-AcSqZFupNC9y9z3VwOuPnsuPq7MKSngyAs-z9Gg6NECDkMztAIznt7pCPJG58hBQx_Lfe_QTaeqEdstWiiE0nAm4gHSeEkw99mvwgyQ0_Sg/file
# Reusing existing connection to ucbc2ac089a1538f231fb7eb046d.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 63234727 (60M) [application/octet-stream]
# Saving to: ‘data/models/standard_half/face_morpher.pt’
#
# data/models/standar 100%[===================>]  60.30M  15.6MB/s    in 3.9s
#
# 2025-07-01 11:27:06 (15.6 MB/s) - ‘data/models/standard_half/face_morpher.pt’ saved [63234727/63234727]
#
# --2025-07-01 11:27:06--  https://www.dropbox.com/s/c5lrn7z34x12317/two_algo_face_body_rotator.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/qgfw2ps6g7a8qbas6tw7x/two_algo_face_body_rotator.pt?rlkey=wpf33euhqzmh1vq5m1x07jya0&dl=0 [following]
# --2025-07-01 11:27:06--  https://www.dropbox.com/scl/fi/qgfw2ps6g7a8qbas6tw7x/two_algo_face_body_rotator.pt?rlkey=wpf33euhqzmh1vq5m1x07jya0&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc55b24840711a60600b7127ee31.dl.dropboxusercontent.com/cd/0/inline/Cso0LVFDFjyIR01S97jAQ4XpFOiBlQ8l69GOa9vwj8UxBUfLb9dJK6tA2IhQNCb-bPV-dygPQOPZlBxg7zPyGDPrInnyf7ra66gGBlqZlD6iFYMHkqE2oT2l8kKaQ8ZSUdI/file# [following]
# --2025-07-01 11:27:07--  https://uc55b24840711a60600b7127ee31.dl.dropboxusercontent.com/cd/0/inline/Cso0LVFDFjyIR01S97jAQ4XpFOiBlQ8l69GOa9vwj8UxBUfLb9dJK6tA2IhQNCb-bPV-dygPQOPZlBxg7zPyGDPrInnyf7ra66gGBlqZlD6iFYMHkqE2oT2l8kKaQ8ZSUdI/file
# Resolving uc55b24840711a60600b7127ee31.dl.dropboxusercontent.com (uc55b24840711a60600b7127ee31.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6022:15::a27d:420f
# Connecting to uc55b24840711a60600b7127ee31.dl.dropboxusercontent.com (uc55b24840711a60600b7127ee31.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CsqfHIWQ3Zcq1SYzzdB0Vvvj_B1truU-YKwFfl6F0WphL-9tUND3gHeXLdJgLQwJpnXWZ7UH-Wd9Dt-7L4NCjjNJsEHTzJiRFp5cZllgfGqadMMSmXVB7k-Hgw0dnBZ7AzilFKl2hhugFMUirNyBx-t2ve1816cVcrF4D-YHAB4yOMA89ZVV8kuHnYdPqGj95QY26gvGuyAmSWIqKH1RMj3kVkM7UMEarOalw7kf4h_Log7VqH3DsoppQHv5sTzrWUHgIXmuqS6SYuUVs37T8NMrSWVf7QAt4hLYuvmyNg-5Gi1vPOgPP3zJzh7Mf3i9TXv8dIsKttgHV4TiekiJg2l68XihiqNiSn9XFPCnuGClEw/file [following]
# --2025-07-01 11:27:07--  https://uc55b24840711a60600b7127ee31.dl.dropboxusercontent.com/cd/0/inline2/CsqfHIWQ3Zcq1SYzzdB0Vvvj_B1truU-YKwFfl6F0WphL-9tUND3gHeXLdJgLQwJpnXWZ7UH-Wd9Dt-7L4NCjjNJsEHTzJiRFp5cZllgfGqadMMSmXVB7k-Hgw0dnBZ7AzilFKl2hhugFMUirNyBx-t2ve1816cVcrF4D-YHAB4yOMA89ZVV8kuHnYdPqGj95QY26gvGuyAmSWIqKH1RMj3kVkM7UMEarOalw7kf4h_Log7VqH3DsoppQHv5sTzrWUHgIXmuqS6SYuUVs37T8NMrSWVf7QAt4hLYuvmyNg-5Gi1vPOgPP3zJzh7Mf3i9TXv8dIsKttgHV4TiekiJg2l68XihiqNiSn9XFPCnuGClEw/file
# Reusing existing connection to uc55b24840711a60600b7127ee31.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 65350735 (62M) [application/octet-stream]
# Saving to: ‘data/models/standard_half/two_algo_face_body_rotator.pt’
#
# data/models/standar 100%[===================>]  62.32M  23.8MB/s    in 2.6s
#
# 2025-07-01 11:27:10 (23.8 MB/s) - ‘data/models/standard_half/two_algo_face_body_rotator.pt’ saved [65350735/65350735]
#
# --2025-07-01 11:27:10--  https://www.dropbox.com/s/nwdxhrpa9fy19r4/editor.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/bdqw1g2wig2g8jtup5ph0/editor.pt?rlkey=p18b39uk4u1cs0yoer2b4ckkn&dl=0 [following]
# --2025-07-01 11:27:11--  https://www.dropbox.com/scl/fi/bdqw1g2wig2g8jtup5ph0/editor.pt?rlkey=p18b39uk4u1cs0yoer2b4ckkn&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc82288d5c69f6ad033ccbe809b8.dl.dropboxusercontent.com/cd/0/inline/CsrVWcWAotwj7XSE6ZdM3tCWnu162jMw-UG4fVJ5PnyS0WNV8ALQ_VGxmYdUYg6NJimrLG3SoJVlLEMlK4y7Li8tvF0OlEwvP0AEBtPv1Sqp-k6vnKmyb3BpPR1yQC0Xj54/file# [following]
# --2025-07-01 11:27:11--  https://uc82288d5c69f6ad033ccbe809b8.dl.dropboxusercontent.com/cd/0/inline/CsrVWcWAotwj7XSE6ZdM3tCWnu162jMw-UG4fVJ5PnyS0WNV8ALQ_VGxmYdUYg6NJimrLG3SoJVlLEMlK4y7Li8tvF0OlEwvP0AEBtPv1Sqp-k6vnKmyb3BpPR1yQC0Xj54/file
# Resolving uc82288d5c69f6ad033ccbe809b8.dl.dropboxusercontent.com (uc82288d5c69f6ad033ccbe809b8.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6021:15::a27d:410f
# Connecting to uc82288d5c69f6ad033ccbe809b8.dl.dropboxusercontent.com (uc82288d5c69f6ad033ccbe809b8.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CspMKYhCYyLSgOeSfJNPqApN4f5kYkjnUayBnLK5eWeZ9qR4XAnFnkiOgGBCy09BEcjm7hIBkIJqP-05XWiepZwzeWdPxX_moKEkHJES0qKl8TJ7RLsd4Rga3gTC6nZAYTzlNJP0PrJtT2JLEtwNGhOLlVR0lWRhT0cEsM164R0IxZLAe_n5tVZHX6eO8oPOfWHL4uvEXgDxCdZ3a3W6EK9qgQ8zYUlPrRKhn2nVrcDcDSdG-kqooRX6ePTA0XSOPRUcJl-o1MpTfcPcF4M7Nm2WxJwQao6HcsN4fOdFCtuP94CxOI2kXwoYM3yk-XjWXobgm_-Kx8bj_S4LE9-D_dHcvWmz1GxamzcNsxkNw3OXQw/file [following]
# --2025-07-01 11:27:12--  https://uc82288d5c69f6ad033ccbe809b8.dl.dropboxusercontent.com/cd/0/inline2/CspMKYhCYyLSgOeSfJNPqApN4f5kYkjnUayBnLK5eWeZ9qR4XAnFnkiOgGBCy09BEcjm7hIBkIJqP-05XWiepZwzeWdPxX_moKEkHJES0qKl8TJ7RLsd4Rga3gTC6nZAYTzlNJP0PrJtT2JLEtwNGhOLlVR0lWRhT0cEsM164R0IxZLAe_n5tVZHX6eO8oPOfWHL4uvEXgDxCdZ3a3W6EK9qgQ8zYUlPrRKhn2nVrcDcDSdG-kqooRX6ePTA0XSOPRUcJl-o1MpTfcPcF4M7Nm2WxJwQao6HcsN4fOdFCtuP94CxOI2kXwoYM3yk-XjWXobgm_-Kx8bj_S4LE9-D_dHcvWmz1GxamzcNsxkNw3OXQw/file
# Reusing existing connection to uc82288d5c69f6ad033ccbe809b8.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3802999 (3.6M) [application/octet-stream]
# Saving to: ‘data/models/separable_float/editor.pt’
#
# data/models/separab 100%[===================>]   3.63M  --.-KB/s    in 0.08s
#
# 2025-07-01 11:27:12 (47.3 MB/s) - ‘data/models/separable_float/editor.pt’ saved [3802999/3802999]
#
# --2025-07-01 11:27:12--  https://www.dropbox.com/s/hfzjcu9cqr9wm3i/eyebrow_decomposer.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/qc01ia5t8k7efttzbcm58/eyebrow_decomposer.pt?rlkey=7c70ystu7oacvq7sz4dovwqtd&dl=0 [following]
# --2025-07-01 11:27:13--  https://www.dropbox.com/scl/fi/qc01ia5t8k7efttzbcm58/eyebrow_decomposer.pt?rlkey=7c70ystu7oacvq7sz4dovwqtd&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc72be4f8ac8fdc419177d134918.dl.dropboxusercontent.com/cd/0/inline/Csp_9B0HVr2C2CEgu7YlEbixe5MBKkKY7VBjZ3UcwDcskr30Q1T4kHH92v7bUFm_OdV8lCXCfI8F76G-V1x-pquZV0cOEUMUnx04wRHuBgocWfjzRFn6DgZiADyoqVNbvEM/file# [following]
# --2025-07-01 11:27:13--  https://uc72be4f8ac8fdc419177d134918.dl.dropboxusercontent.com/cd/0/inline/Csp_9B0HVr2C2CEgu7YlEbixe5MBKkKY7VBjZ3UcwDcskr30Q1T4kHH92v7bUFm_OdV8lCXCfI8F76G-V1x-pquZV0cOEUMUnx04wRHuBgocWfjzRFn6DgZiADyoqVNbvEM/file
# Resolving uc72be4f8ac8fdc419177d134918.dl.dropboxusercontent.com (uc72be4f8ac8fdc419177d134918.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6022:15::a27d:420f
# Connecting to uc72be4f8ac8fdc419177d134918.dl.dropboxusercontent.com (uc72be4f8ac8fdc419177d134918.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CsqpaxzMh3f-CZu5i5qTQBOcuoZKAzySlpTA7ZqWjYJddgGOjvQQpQIeSyS_Z507uz6jxXZnE8qv0uCYK5dHIbpLzhdDBe6VB-GpDvOPi6aengzVjitulio7tpi_5JBE18iwgXy-xpp-oKC4fvA3x87HU7Vk6ZGPJH5DA5aQvn_ytz-BY1gr7mvj6RMRbJ6A0IIQysm3hVWgBxKgFNmJCIPEoOVxiHUf5n5MsNtcuN1eFwM3LIOMZ5SIjZgEk0dDyD_sO13xQNpI2DA5koMPg8qZ7o7xNx09rFqXBAA39Jnk3cehokmf38AMx5_2xEhjmerHO4tSNEpWNCSx0h7rtt3hT2VK-32zikdJBZOnQ867qQ/file [following]
# --2025-07-01 11:27:14--  https://uc72be4f8ac8fdc419177d134918.dl.dropboxusercontent.com/cd/0/inline2/CsqpaxzMh3f-CZu5i5qTQBOcuoZKAzySlpTA7ZqWjYJddgGOjvQQpQIeSyS_Z507uz6jxXZnE8qv0uCYK5dHIbpLzhdDBe6VB-GpDvOPi6aengzVjitulio7tpi_5JBE18iwgXy-xpp-oKC4fvA3x87HU7Vk6ZGPJH5DA5aQvn_ytz-BY1gr7mvj6RMRbJ6A0IIQysm3hVWgBxKgFNmJCIPEoOVxiHUf5n5MsNtcuN1eFwM3LIOMZ5SIjZgEk0dDyD_sO13xQNpI2DA5koMPg8qZ7o7xNx09rFqXBAA39Jnk3cehokmf38AMx5_2xEhjmerHO4tSNEpWNCSx0h7rtt3hT2VK-32zikdJBZOnQ867qQ/file
# Reusing existing connection to uc72be4f8ac8fdc419177d134918.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13313007 (13M) [application/octet-stream]
# Saving to: ‘data/models/separable_float/eyebrow_decomposer.pt’
#
# data/models/separab 100%[===================>]  12.70M  27.0MB/s    in 0.5s
#
# 2025-07-01 11:27:15 (27.0 MB/s) - ‘data/models/separable_float/eyebrow_decomposer.pt’ saved [13313007/13313007]
#
# --2025-07-01 11:27:15--  https://www.dropbox.com/s/g04dyyyavh5o1e2/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/u59spi0326z8lcv91idfq/eyebrow_morphing_combiner.pt?rlkey=8wea2s6bfaa3tgevfc60q8q9t&dl=0 [following]
# --2025-07-01 11:27:15--  https://www.dropbox.com/scl/fi/u59spi0326z8lcv91idfq/eyebrow_morphing_combiner.pt?rlkey=8wea2s6bfaa3tgevfc60q8q9t&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc939b41d46132575b1f1ecd9faf.dl.dropboxusercontent.com/cd/0/inline/CsrzQkhJVRBvqlIV8ohcAIjhVUap9C0k3Ebpi8YH15uYNico5vGDxDY-2jcDK8e4I0lzNfqkvaBC1XdOiYkfETxqM8XY0X9jUTk1JBRHhJJ4FJjjfG-UrclehwD2ZgouAes/file# [following]
# --2025-07-01 11:27:15--  https://uc939b41d46132575b1f1ecd9faf.dl.dropboxusercontent.com/cd/0/inline/CsrzQkhJVRBvqlIV8ohcAIjhVUap9C0k3Ebpi8YH15uYNico5vGDxDY-2jcDK8e4I0lzNfqkvaBC1XdOiYkfETxqM8XY0X9jUTk1JBRHhJJ4FJjjfG-UrclehwD2ZgouAes/file
# Resolving uc939b41d46132575b1f1ecd9faf.dl.dropboxusercontent.com (uc939b41d46132575b1f1ecd9faf.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6027:15::a27d:480f
# Connecting to uc939b41d46132575b1f1ecd9faf.dl.dropboxusercontent.com (uc939b41d46132575b1f1ecd9faf.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CspmvMqpuHM4i_IMYcMVSPC-XuGa3--iZ-1V0TQEGMpV0gEw4rQJ165BplKl-XZCIH6LyizR0OIQ2A0OBG06hpWWMXEmgdF2v_lnCIbBBBbYCdOPpctP9V6osBfC7emeDMEs92ZwDxkRPwxSl85GJsxnenhqmZbXw8XG6JKkTYXFyMl_R7cFzaANjOUagM0GmB80a1hHphdyDin21iN7m8w5D00oFhSSptdGUa0VxiLgq3x12ACt7RV6ciKXU0PkpC8d8_EsMztgXl8BMY8aUSBQIpjLqDzrmGBqMcKxWTBjavExbnKpT_vCruVARA9Gn6IOqUQjKfqls7Z3sAxPkWIoSait57yFFfxWEtyhNh-1zQ/file [following]
# --2025-07-01 11:27:16--  https://uc939b41d46132575b1f1ecd9faf.dl.dropboxusercontent.com/cd/0/inline2/CspmvMqpuHM4i_IMYcMVSPC-XuGa3--iZ-1V0TQEGMpV0gEw4rQJ165BplKl-XZCIH6LyizR0OIQ2A0OBG06hpWWMXEmgdF2v_lnCIbBBBbYCdOPpctP9V6osBfC7emeDMEs92ZwDxkRPwxSl85GJsxnenhqmZbXw8XG6JKkTYXFyMl_R7cFzaANjOUagM0GmB80a1hHphdyDin21iN7m8w5D00oFhSSptdGUa0VxiLgq3x12ACt7RV6ciKXU0PkpC8d8_EsMztgXl8BMY8aUSBQIpjLqDzrmGBqMcKxWTBjavExbnKpT_vCruVARA9Gn6IOqUQjKfqls7Z3sAxPkWIoSait57yFFfxWEtyhNh-1zQ/file
# Reusing existing connection to uc939b41d46132575b1f1ecd9faf.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13334119 (13M) [application/octet-stream]
# Saving to: ‘data/models/separable_float/eyebrow_morphing_combiner.pt’
#
# data/models/separab 100%[===================>]  12.72M  11.9MB/s    in 1.1s
#
# 2025-07-01 11:27:18 (11.9 MB/s) - ‘data/models/separable_float/eyebrow_morphing_combiner.pt’ saved [13334119/13334119]
#
# --2025-07-01 11:27:18--  https://www.dropbox.com/s/vgi9dsj95y0rrwv/face_morpher.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/lmigcugjnm61xac95hdjk/face_morpher.pt?rlkey=fpn603hd1xdqbgrrwjb6knm5t&dl=0 [following]
# --2025-07-01 11:27:18--  https://www.dropbox.com/scl/fi/lmigcugjnm61xac95hdjk/face_morpher.pt?rlkey=fpn603hd1xdqbgrrwjb6knm5t&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc13b831f7fad984967f199269cf.dl.dropboxusercontent.com/cd/0/inline/Csou7FWCOdCnjc7ijPoOnX8JzWrs9Pe9bE4bgGFDRlyd4N6tvjj_jEmj1u0Urke9ezmAvwmHqkQO68W94JngIYMJz4InOkDbcpUlA5OMvzTD40uv4lZKBUFRxashHjEzYlo/file# [following]
# --2025-07-01 11:27:18--  https://uc13b831f7fad984967f199269cf.dl.dropboxusercontent.com/cd/0/inline/Csou7FWCOdCnjc7ijPoOnX8JzWrs9Pe9bE4bgGFDRlyd4N6tvjj_jEmj1u0Urke9ezmAvwmHqkQO68W94JngIYMJz4InOkDbcpUlA5OMvzTD40uv4lZKBUFRxashHjEzYlo/file
# Resolving uc13b831f7fad984967f199269cf.dl.dropboxusercontent.com (uc13b831f7fad984967f199269cf.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6021:15::a27d:410f
# Connecting to uc13b831f7fad984967f199269cf.dl.dropboxusercontent.com (uc13b831f7fad984967f199269cf.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CsqD3Troji1hOvJUHZIedeXc_JxXdR3e_J_Pmsqn-JUqE99Vom1uTJ2bAAuBpnFbpKAMjiDC0VdINZhYgnRPDAgcgZzcfFgKZxlPSl50gkMfkwSNxpf6wfkpxbxG_le1Arfh1KfZDcFNOnbPdc5MLPdkQyqKmqrqDkH-q7kacRgRVQLurOiTUZuxeInfEN90OrZKDalkLHXxf2clV-Dcxt3rTbJG4VtrUcCUgkW1jsqEGBpqCvZHH2L32KjRN-dLXJOpKrVe7usRWJkoD6LGnlJ2Q0iHzFaWwwbki16Qj999gysS6eFD-gOqPjogVajRxnrG8CqBDiOxinRFR8-j2vW123Awx3HXBHWpfsdsVMOByg/file [following]
# --2025-07-01 11:27:19--  https://uc13b831f7fad984967f199269cf.dl.dropboxusercontent.com/cd/0/inline2/CsqD3Troji1hOvJUHZIedeXc_JxXdR3e_J_Pmsqn-JUqE99Vom1uTJ2bAAuBpnFbpKAMjiDC0VdINZhYgnRPDAgcgZzcfFgKZxlPSl50gkMfkwSNxpf6wfkpxbxG_le1Arfh1KfZDcFNOnbPdc5MLPdkQyqKmqrqDkH-q7kacRgRVQLurOiTUZuxeInfEN90OrZKDalkLHXxf2clV-Dcxt3rTbJG4VtrUcCUgkW1jsqEGBpqCvZHH2L32KjRN-dLXJOpKrVe7usRWJkoD6LGnlJ2Q0iHzFaWwwbki16Qj999gysS6eFD-gOqPjogVajRxnrG8CqBDiOxinRFR8-j2vW123Awx3HXBHWpfsdsVMOByg/file
# Reusing existing connection to uc13b831f7fad984967f199269cf.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13374071 (13M) [application/octet-stream]
# Saving to: ‘data/models/separable_float/face_morpher.pt’
#
# data/models/separab 100%[===================>]  12.75M  23.8MB/s    in 0.5s
#
# 2025-07-01 11:27:20 (23.8 MB/s) - ‘data/models/separable_float/face_morpher.pt’ saved [13374071/13374071]
#
# --2025-07-01 11:27:20--  https://www.dropbox.com/s/8u0qond8po34l24/two_algo_face_body_rotator.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/v0eb6dyk7kj8tphy8ycbq/two_algo_face_body_rotator.pt?rlkey=cihbim8nm1dzpdqnice3i8w6m&dl=0 [following]
# --2025-07-01 11:27:20--  https://www.dropbox.com/scl/fi/v0eb6dyk7kj8tphy8ycbq/two_algo_face_body_rotator.pt?rlkey=cihbim8nm1dzpdqnice3i8w6m&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc405734ca5de31b9b6f7c295ebf.dl.dropboxusercontent.com/cd/0/inline/CsqgBs5IA_ex9SRe0Mb_Lcfxk87wqonOMmvfAA-h84Bf95MSGJzJJ9H0JCXo7iCINAgNUtkVQtFRcfLifdL-P9znsB95n9ak8a8z7LDoaJ7s9Eoh6PUcFNZ09y5sJMX6x7A/file# [following]
# --2025-07-01 11:27:21--  https://uc405734ca5de31b9b6f7c295ebf.dl.dropboxusercontent.com/cd/0/inline/CsqgBs5IA_ex9SRe0Mb_Lcfxk87wqonOMmvfAA-h84Bf95MSGJzJJ9H0JCXo7iCINAgNUtkVQtFRcfLifdL-P9znsB95n9ak8a8z7LDoaJ7s9Eoh6PUcFNZ09y5sJMX6x7A/file
# Resolving uc405734ca5de31b9b6f7c295ebf.dl.dropboxusercontent.com (uc405734ca5de31b9b6f7c295ebf.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6022:15::a27d:420f
# Connecting to uc405734ca5de31b9b6f7c295ebf.dl.dropboxusercontent.com (uc405734ca5de31b9b6f7c295ebf.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CsoavoCJvM9TjWvEJTGAHiMsSXjCqM4hkPP6jQDdOYV0mjt8-pz5K-KGUAva5GSabtcslBygyDBj4ToL7ACEIAWGtNl_VgyYqdd-tBBurajImUrU7HcUczgnTmUurMV8DlNO8SR5sv7vTg2u0R3DqSOBXPoSCTPoqVmYOo1T4kZ5FzfclScxFh8mjkVoGpS34-UXWWqCA0Gy6lV1Hodq2QLO3Xpd1MoQMNZj_0EpI4Z6jG2jLHXFK4ybxhcOqYExNyUyY3xp-65JgdqS5Jjl4pnrcVMEWUCmB604YtGzIByDT_WBd6_dZ_cfxr0oP2kG2g64M9nx1CUnD4cWHvdPLIYFT2RmnFMY8BSQWePXaEWHuA/file [following]
# --2025-07-01 11:27:22--  https://uc405734ca5de31b9b6f7c295ebf.dl.dropboxusercontent.com/cd/0/inline2/CsoavoCJvM9TjWvEJTGAHiMsSXjCqM4hkPP6jQDdOYV0mjt8-pz5K-KGUAva5GSabtcslBygyDBj4ToL7ACEIAWGtNl_VgyYqdd-tBBurajImUrU7HcUczgnTmUurMV8DlNO8SR5sv7vTg2u0R3DqSOBXPoSCTPoqVmYOo1T4kZ5FzfclScxFh8mjkVoGpS34-UXWWqCA0Gy6lV1Hodq2QLO3Xpd1MoQMNZj_0EpI4Z6jG2jLHXFK4ybxhcOqYExNyUyY3xp-65JgdqS5Jjl4pnrcVMEWUCmB604YtGzIByDT_WBd6_dZ_cfxr0oP2kG2g64M9nx1CUnD4cWHvdPLIYFT2RmnFMY8BSQWePXaEWHuA/file
# Reusing existing connection to uc405734ca5de31b9b6f7c295ebf.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14355239 (14M) [application/octet-stream]
# Saving to: ‘data/models/separable_float/two_algo_face_body_rotator.pt’
#
# data/models/separab 100%[===================>]  13.69M  18.5MB/s    in 0.7s
#
# 2025-07-01 11:27:23 (18.5 MB/s) - ‘data/models/separable_float/two_algo_face_body_rotator.pt’ saved [14355239/14355239]
#
# --2025-07-01 11:27:23--  https://www.dropbox.com/s/on8kn6z9fj95j0h/editor.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/c6kw58887mrtlestxyh1h/editor.pt?rlkey=kk35puvwaj35529ppaxlea8v9&dl=0 [following]
# --2025-07-01 11:27:23--  https://www.dropbox.com/scl/fi/c6kw58887mrtlestxyh1h/editor.pt?rlkey=kk35puvwaj35529ppaxlea8v9&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd3106a93d6d35e3147230d9d48.dl.dropboxusercontent.com/cd/0/inline/CsrWzx3xeBzpUPGUHkN7ZSLeJ0bG-0SvpSIdvTlVefNcSM9pNtLKx-gbmZv1A1DXcJJC7H7kY40-TRtKzxVsXebybsbZU5dbda89u7P-YZxut_fuQHdTXKeM3-yVVN9u4DA/file# [following]
# --2025-07-01 11:27:24--  https://ucd3106a93d6d35e3147230d9d48.dl.dropboxusercontent.com/cd/0/inline/CsrWzx3xeBzpUPGUHkN7ZSLeJ0bG-0SvpSIdvTlVefNcSM9pNtLKx-gbmZv1A1DXcJJC7H7kY40-TRtKzxVsXebybsbZU5dbda89u7P-YZxut_fuQHdTXKeM3-yVVN9u4DA/file
# Resolving ucd3106a93d6d35e3147230d9d48.dl.dropboxusercontent.com (ucd3106a93d6d35e3147230d9d48.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6021:15::a27d:410f
# Connecting to ucd3106a93d6d35e3147230d9d48.dl.dropboxusercontent.com (ucd3106a93d6d35e3147230d9d48.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Csr0qHp3sjmft1OM7d2qwOmvMuID6V8njqUbQhmJG6rxCV-5oTmbAl6fXHQbzw_KN14DA7vOE1rkZROxPPlqCrwujGkyMZcJtqB_LRHTGGJeQ-0P1f7AsRLYBcwj5TCu5i616n8vgPtckviaEr0tHHyeTZSgKlz1Ws1SBKW668nZ_LzlzjBLacWIO49deZDvFBwnCp4LKg3NlXhMGJu9CqcpW3SrYmOoysrunr6jyK9oAlfw7YtNL5uf3bVp0qnlD459X9-RdmPK3TuFr2wVETRMkVQcVwvprsAJjJ_Wk9LjniebO-CU4BTByEAzWsNciooDxSk_V5L9Tq1A5gPiyVpXH7IOhfEqr45WX6-HwXXqJQ/file [following]
# --2025-07-01 11:27:24--  https://ucd3106a93d6d35e3147230d9d48.dl.dropboxusercontent.com/cd/0/inline2/Csr0qHp3sjmft1OM7d2qwOmvMuID6V8njqUbQhmJG6rxCV-5oTmbAl6fXHQbzw_KN14DA7vOE1rkZROxPPlqCrwujGkyMZcJtqB_LRHTGGJeQ-0P1f7AsRLYBcwj5TCu5i616n8vgPtckviaEr0tHHyeTZSgKlz1Ws1SBKW668nZ_LzlzjBLacWIO49deZDvFBwnCp4LKg3NlXhMGJu9CqcpW3SrYmOoysrunr6jyK9oAlfw7YtNL5uf3bVp0qnlD459X9-RdmPK3TuFr2wVETRMkVQcVwvprsAJjJ_Wk9LjniebO-CU4BTByEAzWsNciooDxSk_V5L9Tq1A5gPiyVpXH7IOhfEqr45WX6-HwXXqJQ/file
# Reusing existing connection to ucd3106a93d6d35e3147230d9d48.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1918327 (1.8M) [application/octet-stream]
# Saving to: ‘data/models/separable_half/editor.pt’
#
# data/models/separab 100%[===================>]   1.83M  --.-KB/s    in 0.06s
#
# 2025-07-01 11:27:25 (29.2 MB/s) - ‘data/models/separable_half/editor.pt’ saved [1918327/1918327]
#
# --2025-07-01 11:27:25--  https://www.dropbox.com/s/0hxu8opu1hmghqe/eyebrow_decomposer.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/npupclffia9t0h0l2ahc4/eyebrow_decomposer.pt?rlkey=ff7ytznb5n5mt6y3pebqlq19o&dl=0 [following]
# --2025-07-01 11:27:25--  https://www.dropbox.com/scl/fi/npupclffia9t0h0l2ahc4/eyebrow_decomposer.pt?rlkey=ff7ytznb5n5mt6y3pebqlq19o&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9f94fd9a07b7ce1781209de3bb.dl.dropboxusercontent.com/cd/0/inline/Csp0joKmif4rrtbjtGZYYF1Uxn_uSvPQXcVPdCz3osFtYPUmsTWSHH8yzSyeAnXfFvJ29m6LhBitkUwDHCrVVcNlQfPbULCOK8IB2BvQ-Pn-gb6i0ECujdoad15SBTt2uX4/file# [following]
# --2025-07-01 11:27:25--  https://uc9f94fd9a07b7ce1781209de3bb.dl.dropboxusercontent.com/cd/0/inline/Csp0joKmif4rrtbjtGZYYF1Uxn_uSvPQXcVPdCz3osFtYPUmsTWSHH8yzSyeAnXfFvJ29m6LhBitkUwDHCrVVcNlQfPbULCOK8IB2BvQ-Pn-gb6i0ECujdoad15SBTt2uX4/file
# Resolving uc9f94fd9a07b7ce1781209de3bb.dl.dropboxusercontent.com (uc9f94fd9a07b7ce1781209de3bb.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6022:15::a27d:420f
# Connecting to uc9f94fd9a07b7ce1781209de3bb.dl.dropboxusercontent.com (uc9f94fd9a07b7ce1781209de3bb.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Csp0RLF-5MihpOs5JlhINkUifDbNtiNvInFJaQYAGK_OMhJpHrizmKEXghYTe8dz3XWTiQlloHKxDuXnK95SwzlmQ067qW793XXKhn_WJ2I3cwSXFfut125NPdPgfnF3OCPc059k6IFVawh4NWMX0cJT2qNxDgq_3iqI9IjSSc3P2pFE1PMztXARXMcDlffJW5eshu7gjYLri5a3J1grp76C01EC3L5qe4tNy6CWtCQdaoAzcrMP0yWu7nHBEYNR2S3Dvn0LPD8TONdH2C7QzSRvszj0_GH_5cSlLo82cEq5ZMkgmFsRkooJtaTNnQvw6QUphA8SuAjxGdKHxeB0hNIkNpj_qJOAeeUclzqW9J1c8Q/file [following]
# --2025-07-01 11:27:26--  https://uc9f94fd9a07b7ce1781209de3bb.dl.dropboxusercontent.com/cd/0/inline2/Csp0RLF-5MihpOs5JlhINkUifDbNtiNvInFJaQYAGK_OMhJpHrizmKEXghYTe8dz3XWTiQlloHKxDuXnK95SwzlmQ067qW793XXKhn_WJ2I3cwSXFfut125NPdPgfnF3OCPc059k6IFVawh4NWMX0cJT2qNxDgq_3iqI9IjSSc3P2pFE1PMztXARXMcDlffJW5eshu7gjYLri5a3J1grp76C01EC3L5qe4tNy6CWtCQdaoAzcrMP0yWu7nHBEYNR2S3Dvn0LPD8TONdH2C7QzSRvszj0_GH_5cSlLo82cEq5ZMkgmFsRkooJtaTNnQvw6QUphA8SuAjxGdKHxeB0hNIkNpj_qJOAeeUclzqW9J1c8Q/file
# Reusing existing connection to uc9f94fd9a07b7ce1781209de3bb.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6673071 (6.4M) [application/octet-stream]
# Saving to: ‘data/models/separable_half/eyebrow_decomposer.pt’
#
# data/models/separab 100%[===================>]   6.36M  22.5MB/s    in 0.3s
#
# 2025-07-01 11:27:27 (22.5 MB/s) - ‘data/models/separable_half/eyebrow_decomposer.pt’ saved [6673071/6673071]
#
# --2025-07-01 11:27:27--  https://www.dropbox.com/s/bgz02afp0xojqfs/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/iaigcorfyl7tn3t4toa3s/eyebrow_morphing_combiner.pt?rlkey=xu3o925wiml52okq2ie73oiu0&dl=0 [following]
# --2025-07-01 11:27:27--  https://www.dropbox.com/scl/fi/iaigcorfyl7tn3t4toa3s/eyebrow_morphing_combiner.pt?rlkey=xu3o925wiml52okq2ie73oiu0&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucaf6c2710776c4749d2aacbe2cb.dl.dropboxusercontent.com/cd/0/inline/CspvVWqL8h_H_zFvvzpeKXe6b29L44Wp5EBcnsVVHgOfsIgCcESy42Tw0HY36YVtR_ZELNI5CZfhhrVTZjauT8HxreR6GqCCArBbGHSUj9DBLA2oNY9urj7V7HT_oYfA5zY/file# [following]
# --2025-07-01 11:27:28--  https://ucaf6c2710776c4749d2aacbe2cb.dl.dropboxusercontent.com/cd/0/inline/CspvVWqL8h_H_zFvvzpeKXe6b29L44Wp5EBcnsVVHgOfsIgCcESy42Tw0HY36YVtR_ZELNI5CZfhhrVTZjauT8HxreR6GqCCArBbGHSUj9DBLA2oNY9urj7V7HT_oYfA5zY/file
# Resolving ucaf6c2710776c4749d2aacbe2cb.dl.dropboxusercontent.com (ucaf6c2710776c4749d2aacbe2cb.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6021:15::a27d:410f
# Connecting to ucaf6c2710776c4749d2aacbe2cb.dl.dropboxusercontent.com (ucaf6c2710776c4749d2aacbe2cb.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CsrzI_RZ7pipmas5fU-KaQXLx0LKVh0XPFVQQxral68eBUCyv96kxHerKJJPItbHj6KHJ85wZIkdsbfiAjUJQGOQcF4TYY59YeN9K60HJbapVjJcgJZM9zeRxa7X-KA9XfTHpI92lqQH9I6UYQxrtRMZq58WqSyzklJmQvMHpb5a_ljjKVufWXn0fvEQm7HWZFpJw-aw_v0jfyawtLjrb3qq1xQoAJYAxRB7o8rkLJy_iLQCnFSOhomfyEIluBcu1K5KjD7Ocdqk_16FXOWCIoxMjiB6nLaVHMZkyVsQ-SOttPuqFh2Zr0olVqhx7QL3j3n3oA96spUvDeY-NknDGhhaqjkHpOQsVuLHh-ZN00BLcQ/file [following]
# --2025-07-01 11:27:28--  https://ucaf6c2710776c4749d2aacbe2cb.dl.dropboxusercontent.com/cd/0/inline2/CsrzI_RZ7pipmas5fU-KaQXLx0LKVh0XPFVQQxral68eBUCyv96kxHerKJJPItbHj6KHJ85wZIkdsbfiAjUJQGOQcF4TYY59YeN9K60HJbapVjJcgJZM9zeRxa7X-KA9XfTHpI92lqQH9I6UYQxrtRMZq58WqSyzklJmQvMHpb5a_ljjKVufWXn0fvEQm7HWZFpJw-aw_v0jfyawtLjrb3qq1xQoAJYAxRB7o8rkLJy_iLQCnFSOhomfyEIluBcu1K5KjD7Ocdqk_16FXOWCIoxMjiB6nLaVHMZkyVsQ-SOttPuqFh2Zr0olVqhx7QL3j3n3oA96spUvDeY-NknDGhhaqjkHpOQsVuLHh-ZN00BLcQ/file
# Reusing existing connection to ucaf6c2710776c4749d2aacbe2cb.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6683431 (6.4M) [application/octet-stream]
# Saving to: ‘data/models/separable_half/eyebrow_morphing_combiner.pt’
#
# data/models/separab 100%[===================>]   6.37M  22.0MB/s    in 0.3s
#
# 2025-07-01 11:27:29 (22.0 MB/s) - ‘data/models/separable_half/eyebrow_morphing_combiner.pt’ saved [6683431/6683431]
#
# --2025-07-01 11:27:29--  https://www.dropbox.com/s/bgz02afp0xojqfs/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/iaigcorfyl7tn3t4toa3s/eyebrow_morphing_combiner.pt?rlkey=xu3o925wiml52okq2ie73oiu0&dl=0 [following]
# --2025-07-01 11:27:29--  https://www.dropbox.com/scl/fi/iaigcorfyl7tn3t4toa3s/eyebrow_morphing_combiner.pt?rlkey=xu3o925wiml52okq2ie73oiu0&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4f2a7cb8c37e31af55af2899e7.dl.dropboxusercontent.com/cd/0/inline/Cspej3M8kVw-0iJ2mV5nOWRDKZ6ZPwBnxtw6NanNMKyIigwXlko-IXn54mvB5b_UE3yCm5I51SOeUqYyC02-mBOaPgdEEaLYje1KZohIyX1unmZuf7Yfzk3ygL0j1t5rP8U/file# [following]
# --2025-07-01 11:27:30--  https://uc4f2a7cb8c37e31af55af2899e7.dl.dropboxusercontent.com/cd/0/inline/Cspej3M8kVw-0iJ2mV5nOWRDKZ6ZPwBnxtw6NanNMKyIigwXlko-IXn54mvB5b_UE3yCm5I51SOeUqYyC02-mBOaPgdEEaLYje1KZohIyX1unmZuf7Yfzk3ygL0j1t5rP8U/file
# Resolving uc4f2a7cb8c37e31af55af2899e7.dl.dropboxusercontent.com (uc4f2a7cb8c37e31af55af2899e7.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6027:15::a27d:480f
# Connecting to uc4f2a7cb8c37e31af55af2899e7.dl.dropboxusercontent.com (uc4f2a7cb8c37e31af55af2899e7.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CspIx_QXFud4uqHCa7zIuTDm948DQ9kAjfVBLDOdM9fq5faLxqCGkHCEcNKiZfIfrB-nPIvte-V8ttfZ0VRVZEIYpU-KQK8l5z-QliwAHpGCbqI3vGgJ7dh8qP6hA0NBqA3CskEkzMg6Lbz6Ma3mVxoM_0YinlMQEN2kerDQUHLCbZsSs6XXp8cQV3BjmArZpypM-gQTwq_Cd7051pDn7-UpEKl27wN5um4-KYPb2DFbPp-ocmnNIgycNDWhOvIf-fjSjO5p1sBXA8CQUCrfoRURSdZhXOB8RUhAo6kimaU8hFU-IPXPBbmfd7ozNfTDBZLwKkQhfp0EhczJH3mElMTs9AgPggNizfQA8hak0Xh2zQ/file [following]
# --2025-07-01 11:27:30--  https://uc4f2a7cb8c37e31af55af2899e7.dl.dropboxusercontent.com/cd/0/inline2/CspIx_QXFud4uqHCa7zIuTDm948DQ9kAjfVBLDOdM9fq5faLxqCGkHCEcNKiZfIfrB-nPIvte-V8ttfZ0VRVZEIYpU-KQK8l5z-QliwAHpGCbqI3vGgJ7dh8qP6hA0NBqA3CskEkzMg6Lbz6Ma3mVxoM_0YinlMQEN2kerDQUHLCbZsSs6XXp8cQV3BjmArZpypM-gQTwq_Cd7051pDn7-UpEKl27wN5um4-KYPb2DFbPp-ocmnNIgycNDWhOvIf-fjSjO5p1sBXA8CQUCrfoRURSdZhXOB8RUhAo6kimaU8hFU-IPXPBbmfd7ozNfTDBZLwKkQhfp0EhczJH3mElMTs9AgPggNizfQA8hak0Xh2zQ/file
# Reusing existing connection to uc4f2a7cb8c37e31af55af2899e7.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6683431 (6.4M) [application/octet-stream]
# Saving to: ‘data/models/separable_half/face_morpher.pt’
#
# data/models/separab 100%[===================>]   6.37M  29.1MB/s    in 0.2s
#
# 2025-07-01 11:27:31 (29.1 MB/s) - ‘data/models/separable_half/face_morpher.pt’ saved [6683431/6683431]
#
# --2025-07-01 11:27:31--  https://www.dropbox.com/s/vr8h2xxltszhw7w/two_algo_face_body_rotator.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/dzgcq5rddjujc5qe62wta/two_algo_face_body_rotator.pt?rlkey=mr1w82q23rs9vmt9tzv5qfdxz&dl=0 [following]
# --2025-07-01 11:27:31--  https://www.dropbox.com/scl/fi/dzgcq5rddjujc5qe62wta/two_algo_face_body_rotator.pt?rlkey=mr1w82q23rs9vmt9tzv5qfdxz&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc150c29537ad85a60b031c54d86.dl.dropboxusercontent.com/cd/0/inline/Csopn48lLTqjwG4BLhqxIhDUdKtawA32F3PlI9ehMr9OyINAIaI6gL2otbsQlysBJ2S-VzjSoYXMy5GK8H5q7bymF7DCCJ-GlHjF1RK2LPuO1skIIMKyBxqxUqIhLUEAX00/file# [following]
# --2025-07-01 11:27:32--  https://uc150c29537ad85a60b031c54d86.dl.dropboxusercontent.com/cd/0/inline/Csopn48lLTqjwG4BLhqxIhDUdKtawA32F3PlI9ehMr9OyINAIaI6gL2otbsQlysBJ2S-VzjSoYXMy5GK8H5q7bymF7DCCJ-GlHjF1RK2LPuO1skIIMKyBxqxUqIhLUEAX00/file
# Resolving uc150c29537ad85a60b031c54d86.dl.dropboxusercontent.com (uc150c29537ad85a60b031c54d86.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6027:15::a27d:480f
# Connecting to uc150c29537ad85a60b031c54d86.dl.dropboxusercontent.com (uc150c29537ad85a60b031c54d86.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CsoRFIoNpcOPES33ZR6cYxfLKrlNzQ5WmGwIWC5T5BdkPyYb3DnIQC9J3irSqNazCc1R4TDdR2MK-33tg-glWewjfDSJ9ra32wH2r8KHgF0A1HpqFO4qbHufW2phpY5rRy25bj9UaRB_1Wj6WhT22B-xMMi0pLxIS8vr6a5BEYLAypfzGQ5o4-EwDwMuY4dbvV3yi47wzc4K1OFpulUFPSxkugPcRA1beLujLlu2nxk7ybNyYzedpEWkHNnQhBm9Ny7cN5o-vnhRPbHqOeXuFRCNPOMm4gjH6SSFAByRDavD-EvblQiv6-czrveKz3s8d10zxr_nP_r7KW_YivTf0NW3U5cr8cHer966dJKda9ms4Q/file [following]
# --2025-07-01 11:27:32--  https://uc150c29537ad85a60b031c54d86.dl.dropboxusercontent.com/cd/0/inline2/CsoRFIoNpcOPES33ZR6cYxfLKrlNzQ5WmGwIWC5T5BdkPyYb3DnIQC9J3irSqNazCc1R4TDdR2MK-33tg-glWewjfDSJ9ra32wH2r8KHgF0A1HpqFO4qbHufW2phpY5rRy25bj9UaRB_1Wj6WhT22B-xMMi0pLxIS8vr6a5BEYLAypfzGQ5o4-EwDwMuY4dbvV3yi47wzc4K1OFpulUFPSxkugPcRA1beLujLlu2nxk7ybNyYzedpEWkHNnQhBm9Ny7cN5o-vnhRPbHqOeXuFRCNPOMm4gjH6SSFAByRDavD-EvblQiv6-czrveKz3s8d10zxr_nP_r7KW_YivTf0NW3U5cr8cHer966dJKda9ms4Q/file
# Reusing existing connection to uc150c29537ad85a60b031c54d86.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7195239 (6.9M) [application/octet-stream]
# Saving to: ‘data/models/separable_half/two_algo_face_body_rotator.pt’
#
# data/models/separab 100%[===================>]   6.86M  39.0MB/s    in 0.2s
#
# 2025-07-01 11:27:33 (39.0 MB/s) - ‘data/models/separable_half/two_algo_face_body_rotator.pt’ saved [7195239/7195239]

# %%
# Set this constant to specify which system variant to use.
MODEL_NAME = "standard_float"

# Load the models.
import torch
DEVICE_NAME = 'cuda'
device = torch.device(DEVICE_NAME)

def load_poser(model: str, device: torch.device):
    print("Using the %s model." % model)
    if model == "standard_float":
        from tha3.poser.modes.standard_float import create_poser
        return create_poser(device)
    elif model == "standard_half":
        from tha3.poser.modes.standard_half import create_poser
        return create_poser(device)
    elif model == "separable_float":
        from tha3.poser.modes.separable_float import create_poser
        return create_poser(device)
    elif model == "separable_half":
        from tha3.poser.modes.separable_half import create_poser
        return create_poser(device)
    else:
        raise RuntimeError("Invalid model: '%s'" % model)

poser = load_poser(MODEL_NAME, DEVICE_NAME)
poser.get_modules();
# Out:
# Using the standard_float model.
# Loading the eyebrow decomposer ... DONE!!!
# Loading the eyebrow morphing conbiner ... DONE!!!
# Loading the face morpher ... DONE!!!
# Loading the face-body rotator ... DONE!!!
# Loading the combiner ... DONE!!!

# %%
# Create the GUI for manipulating character images.
import PIL.Image
import io
from io import StringIO, BytesIO
import IPython.display
import numpy
import ipywidgets
import time
import threading
import torch
from tha3.util import resize_PIL_image, extract_PIL_image_from_filelike, \
    extract_pytorch_image_from_PIL_image, convert_output_image_from_torch_to_numpy

FRAME_RATE = 30.0

last_torch_input_image = None
torch_input_image = None

def show_pytorch_image(pytorch_image):
    output_image = pytorch_image.detach().cpu()
    numpy_image = numpy.uint8(numpy.rint(convert_output_image_from_torch_to_numpy(output_image) * 255.0))
    pil_image = PIL.Image.fromarray(numpy_image, mode='RGBA')
    IPython.display.display(pil_image)

upload_input_image_button = ipywidgets.FileUpload(
    accept='.png',
    multiple=False,
    layout={
        'width': '512px'
    }
)

output_image_widget = ipywidgets.Output(
    layout={
        'border': '1px solid black',
        'width': '512px',
        'height': '512px'
    }
)

eyebrow_dropdown = ipywidgets.Dropdown(
    options=["troubled", "angry", "lowered", "raised", "happy", "serious"],
    value="troubled",
    description="Eyebrow:",
)
eyebrow_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Left:",
    readout=True,
    readout_format=".2f"
)
eyebrow_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Right:",
    readout=True,
    readout_format=".2f"
)

eye_dropdown = ipywidgets.Dropdown(
    options=["wink", "happy_wink", "surprised", "relaxed", "unimpressed", "raised_lower_eyelid"],
    value="wink",
    description="Eye:",
)
eye_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Left:",
    readout=True,
    readout_format=".2f"
)
eye_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Right:",
    readout=True,
    readout_format=".2f"
)

mouth_dropdown = ipywidgets.Dropdown(
    options=["aaa", "iii", "uuu", "eee", "ooo", "delta", "lowered_corner", "raised_corner", "smirk"],
    value="aaa",
    description="Mouth:",
)
mouth_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Value:",
    readout=True,
    readout_format=".2f"
)
mouth_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description=" ",
    readout=True,
    readout_format=".2f",
    disabled=True,
)

def update_mouth_sliders(change):
    if mouth_dropdown.value == "lowered_corner" or mouth_dropdown.value == "raised_corner":
        mouth_left_slider.description = "Left:"
        mouth_right_slider.description = "Right:"
        mouth_right_slider.disabled = False
    else:
        mouth_left_slider.description = "Value:"
        mouth_right_slider.description = " "
        mouth_right_slider.disabled = True

mouth_dropdown.observe(update_mouth_sliders, names='value')

iris_small_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Left:",
    readout=True,
    readout_format=".2f"
)
iris_small_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Right:",
    readout=True,
    readout_format=".2f",
)
iris_rotation_x_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="X-axis:",
    readout=True,
    readout_format=".2f"
)
iris_rotation_y_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Y-axis:",
    readout=True,
    readout_format=".2f",
)

head_x_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="X-axis:",
    readout=True,
    readout_format=".2f"
)
head_y_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Y-axis:",
    readout=True,
    readout_format=".2f",
)
neck_z_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Z-axis:",
    readout=True,
    readout_format=".2f",
)
body_y_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Y-axis rotation:",
    readout=True,
    readout_format=".2f",
)
body_z_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Z-axis rotation:",
    readout=True,
    readout_format=".2f",
)
breathing_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Breathing:",
    readout=True,
    readout_format=".2f",
)


control_panel = ipywidgets.VBox([
    eyebrow_dropdown,
    eyebrow_left_slider,
    eyebrow_right_slider,
    ipywidgets.HTML(value="<hr>"),
    eye_dropdown,
    eye_left_slider,
    eye_right_slider,
    ipywidgets.HTML(value="<hr>"),
    mouth_dropdown,
    mouth_left_slider,
    mouth_right_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Iris Shrinkage</b></center>"),
    iris_small_left_slider,
    iris_small_right_slider,
    ipywidgets.HTML(value="<center><b>Iris Rotation</b></center>"),
    iris_rotation_x_slider,
    iris_rotation_y_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Head Rotation</b></center>"),
    head_x_slider,
    head_y_slider,
    neck_z_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Body Rotation</b></center>"),
    body_y_slider,
    body_z_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Breathing</b></center>"),
    breathing_slider,
])

controls = ipywidgets.HBox([
    ipywidgets.VBox([
        output_image_widget,
        upload_input_image_button
    ]),
    control_panel,
])

from tha3.poser.modes.pose_parameters import get_pose_parameters
pose_parameters = get_pose_parameters()
pose_size = poser.get_num_parameters()
last_pose = torch.zeros(1, pose_size, dtype=poser.get_dtype()).to(device)

iris_small_left_index = pose_parameters.get_parameter_index("iris_small_left")
iris_small_right_index = pose_parameters.get_parameter_index("iris_small_right")
iris_rotation_x_index = pose_parameters.get_parameter_index("iris_rotation_x")
iris_rotation_y_index = pose_parameters.get_parameter_index("iris_rotation_y")
head_x_index = pose_parameters.get_parameter_index("head_x")
head_y_index = pose_parameters.get_parameter_index("head_y")
neck_z_index = pose_parameters.get_parameter_index("neck_z")
body_y_index = pose_parameters.get_parameter_index("body_y")
body_z_index = pose_parameters.get_parameter_index("body_z")
breathing_index = pose_parameters.get_parameter_index("breathing")

def get_pose():
    pose = torch.zeros(1, pose_size, dtype=poser.get_dtype())

    eyebrow_name = f"eyebrow_{eyebrow_dropdown.value}"
    eyebrow_left_index = pose_parameters.get_parameter_index(f"{eyebrow_name}_left")
    eyebrow_right_index = pose_parameters.get_parameter_index(f"{eyebrow_name}_right")
    pose[0, eyebrow_left_index] = eyebrow_left_slider.value
    pose[0, eyebrow_right_index] = eyebrow_right_slider.value

    eye_name = f"eye_{eye_dropdown.value}"
    eye_left_index = pose_parameters.get_parameter_index(f"{eye_name}_left")
    eye_right_index = pose_parameters.get_parameter_index(f"{eye_name}_right")
    pose[0, eye_left_index] = eye_left_slider.value
    pose[0, eye_right_index] = eye_right_slider.value

    mouth_name = f"mouth_{mouth_dropdown.value}"
    if mouth_name == "mouth_lowered_corner" or mouth_name == "mouth_raised_corner":
        mouth_left_index = pose_parameters.get_parameter_index(f"{mouth_name}_left")
        mouth_right_index = pose_parameters.get_parameter_index(f"{mouth_name}_right")
        pose[0, mouth_left_index] = mouth_left_slider.value
        pose[0, mouth_right_index] = mouth_right_slider.value
    else:
        mouth_index = pose_parameters.get_parameter_index(mouth_name)
        pose[0, mouth_index] = mouth_left_slider.value

    pose[0, iris_small_left_index] = iris_small_left_slider.value
    pose[0, iris_small_right_index] = iris_small_right_slider.value
    pose[0, iris_rotation_x_index] = iris_rotation_x_slider.value
    pose[0, iris_rotation_y_index] = iris_rotation_y_slider.value
    pose[0, head_x_index] = head_x_slider.value
    pose[0, head_y_index] = head_y_slider.value
    pose[0, neck_z_index] = neck_z_slider.value
    pose[0, body_y_index] = body_y_slider.value
    pose[0, body_z_index] = body_z_slider.value
    pose[0, breathing_index] = breathing_slider.value

    return pose.to(device)

display(controls)

def update(change):
    global last_pose
    global last_torch_input_image

    if torch_input_image is None:
        return

    needs_update = False
    if last_torch_input_image is None:
        needs_update = True
    else:
        if (torch_input_image - last_torch_input_image).abs().max().item() > 0:
            needs_update = True

    pose = get_pose()
    if (pose - last_pose).abs().max().item() > 0:
        needs_update = True

    if not needs_update:
        return

    output_image = poser.pose(torch_input_image, pose)[0]
    with output_image_widget:
        output_image_widget.clear_output(wait=True)
        show_pytorch_image(output_image)

    last_torch_input_image = torch_input_image
    last_pose = pose

def upload_image(change):
    global torch_input_image
    for name, file_info in upload_input_image_button.value.items():
        content = io.BytesIO(file_info['content'])
    if content is not None:
        pil_image = resize_PIL_image(extract_PIL_image_from_filelike(content), size=(512,512))
        w, h = pil_image.size
        if pil_image.mode != 'RGBA':
            with output_image_widget:
                torch_input_image = None
                output_image_widget.clear_output(wait=True)
                display(ipywidgets.HTML("Image must have an alpha channel!!!"))
        else:
            torch_input_image = extract_pytorch_image_from_PIL_image(pil_image).to(device)
            if poser.get_dtype() == torch.half:
                torch_input_image = torch_input_image.half()
        update(None)

upload_input_image_button.observe(upload_image, names='value')
eyebrow_dropdown.observe(update, 'value')
eyebrow_left_slider.observe(update, 'value')
eyebrow_right_slider.observe(update, 'value')
eye_dropdown.observe(update, 'value')
eye_left_slider.observe(update, 'value')
eye_right_slider.observe(update, 'value')
mouth_dropdown.observe(update, 'value')
mouth_left_slider.observe(update, 'value')
mouth_right_slider.observe(update, 'value')
iris_small_left_slider.observe(update, 'value')
iris_small_right_slider.observe(update, 'value')
iris_rotation_x_slider.observe(update, 'value')
iris_rotation_y_slider.observe(update, 'value')
head_x_slider.observe(update, 'value')
head_y_slider.observe(update, 'value')
neck_z_slider.observe(update, 'value')
body_y_slider.observe(update, 'value')
body_z_slider.observe(update, 'value')
breathing_slider.observe(update, 'value')
# Out:
# HBox(children=(VBox(children=(Output(layout=Layout(border='1px solid black', height='512px', width='512px')), …
